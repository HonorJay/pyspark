# %%
from pyspark.sql import SparkSession

# %%
spark = SparkSession.builder.appName('Basics').getOrCreate()

# %%
df = spark.read.json('/FileStore/tables/people.json')

# %%
df.show()
# Out:
# +----+-------+
# | age|   name|
# +----+-------+
# |null|Michael|
# |  30|   Andy|
# |  19| Justin|
# +----+-------+

# %%
df.printSchema()
# Out:
# root
#  |-- age: long (nullable = true)
#  |-- name: string (nullable = true)

# %%
df.columns
# Out:
# Out[4]: ['age', 'name']

# %%
df.describe()
# Out:
# Out[5]: DataFrame[summary: string, age: string, name: string]

# %%
df.describe().show()
# Out:
# +-------+------------------+-------+
# |summary|               age|   name|
# +-------+------------------+-------+
# |  count|                 2|      3|
# |   mean|              24.5|   null|
# | stddev|7.7781745930520225|   null|
# |    min|                19|   Andy|
# |    max|                30|Michael|
# +-------+------------------+-------+

# %%
from pyspark.sql.types import StructField, StringType, IntegerType, StructType

# %%
data_schema = [StructField('age', IntegerType(), True),
               StructField('name', StringType(), True)]

# %%
final_struc = StructType(fields = data_schema)

# %%
df = spark.read.json('/FileStore/tables/people.json', schema=final_struc)

# %%
df.printSchema()
# Out:
# root
#  |-- age: integer (nullable = true)
#  |-- name: string (nullable = true)

# %% [markdown]
# last time
# ----------------------------------------------------------------------------
# ----------------------------------------------------------------------------
# this time
# ----------------------------------------------------------------------------

# %%
df['age']
# Out:
# Out[12]: Column<'age'>

# %%
type(df['age'])
# Out:
# Out[13]: pyspark.sql.column.Column

# %%
df.select('age')
# Out:
# Out[14]: DataFrame[age: int]

# %%
df.select('age').show()
# Out:
# +----+
# | age|
# +----+
# |null|
# |  30|
# |  19|
# +----+

# %%
type(df.select('age'))
# Out:
# Out[16]: pyspark.sql.dataframe.DataFrame

# %%
df.select(['age','name'])
# Out:
# Out[17]: DataFrame[age: int, name: string]

# %%
df.select(['age','name']).show()
# Out:
# +----+-------+
# | age|   name|
# +----+-------+
# |null|Michael|
# |  30|   Andy|
# |  19| Justin|
# +----+-------+

# %%
# 새로운 컬럼 추가
df.withColumn('double_age', df['age']*2).show()
# Out:
# +----+-------+----------+
# | age|   name|double_age|
# +----+-------+----------+
# |null|Michael|      null|
# |  30|   Andy|        60|
# |  19| Justin|        38|
# +----+-------+----------+

# %%
# 데이터프레임을 임시 뷰로 만들기
df.createOrReplaceTempView('people')

# %%
results = spark.sql("SELECT * FROM people")

# %%
results.show()
# Out:
# +----+-------+
# | age|   name|
# +----+-------+
# |null|Michael|
# |  30|   Andy|
# |  19| Justin|
# +----+-------+

# %%
new_results = spark.sql("SELECT * FROM people WHERE age=30")

# %%
new_results.show()
# Out:
# +---+----+
# |age|name|
# +---+----+
# | 30|Andy|
# +---+----+
